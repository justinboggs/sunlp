# %%
import pandas as pd
import plotly.express as px

# %%
data = pd.read_csv('data/sites/kpi10808.csv')
data.head()
# Out:
#    Site_ID Grade_Description        Date  Price  Profit   Volume  \
# 0    10808       Premium Gas  2019-01-01  2.319    7.60    49.30
# 1    10808      Unleaded Gas  2019-01-01  1.769    9.73  1092.01
# 2    10808       Premium Gas  2019-01-02  2.309   14.78    83.84
# 3    10808      Unleaded Gas  2019-01-02  1.759   11.13  1955.47
# 4    10808       Premium Gas  2019-01-03  2.299    7.15    56.94
#
#    Competitor_Price  Fuel_Cost
# 0          1.799000   1.534257
# 1          1.825667   1.323700
# 2          1.799000   1.535803
# 3          1.819000   1.325600
# 4          1.799000   1.553484

# %%
data['Date'] = pd.to_datetime(data['Date'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1603 entries, 0 to 1602
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Site_ID            1603 non-null   int64
#  1   Grade_Description  1603 non-null   object
#  2   Date               1603 non-null   datetime64[ns]
#  3   Price              1603 non-null   float64
#  4   Profit             1603 non-null   float64
#  5   Volume             1603 non-null   float64
#  6   Competitor_Price   1603 non-null   float64
#  7   Fuel_Cost          1603 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(1), object(1)
# memory usage: 100.3+ KB

# %%
fig = px.line(data, x='Date', y='Price', template='plotly_dark')
fig.show()
# Out:
# <div>                            <div id="46e39738-f549-407f-bf6d-828db29251ee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46e39738-f549-407f-bf6d-828db29251ee")) {                    Plotly.newPlot(                        "46e39738-f549-407f-bf6d-828db29251ee",                        [{"hovertemplate": "Date=%{x}<br>Price=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scattergl", "x": ["2019-01-01T00:00:00", "2019-01-01T00:00:00", "2019-01-02T00:00:00", "2019-01-02T00:00:00", "2019-01-03T00:00:00", "2019-01-03T00:00:00", "2019-01-04T00:00:00", "2019-01-04T00:00:00", "2019-01-05T00:00:00", "2019-01-05T00:00:00", "2019-01-06T00:00:00", "2019-01-07
# ...
