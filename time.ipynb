# %%
import pandas as pd
import datetime as dt

# %%
data = pd.read_csv('data/site_kpis.csv')
data.head()
# Out:
#    Site_ID Grade_Description        Date  Price  Fuel Cost  Profit   Volume  \
# 0    10808       Premium Gas  2019-01-01  2.319   1.534257    7.60    49.30
# 1    10808      Unleaded Gas  2019-01-01  1.769   1.323700    9.73  1092.01
# 2    10808       Premium Gas  2019-01-02  2.309   1.535803   14.78    83.84
# 3    10808      Unleaded Gas  2019-01-02  1.759   1.325600   11.13  1955.47
# 4    10808       Premium Gas  2019-01-03  2.299   1.553484    7.15    56.94
#
#    Competitor_Price
# 0          1.799000
# 1          1.825667
# 2          1.799000
# 3          1.819000
# 4          1.799000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5713 entries, 0 to 5712
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Site_ID            5713 non-null   int64
#  1   Grade_Description  5713 non-null   object
#  2   Date               5713 non-null   object
#  3   Price              5713 non-null   float64
#  4   Fuel Cost          5713 non-null   float64
#  5   Profit             5713 non-null   float64
#  6   Volume             5713 non-null   float64
#  7   Competitor_Price   5713 non-null   float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 357.2+ KB

# %%
data['Date'] = pd.to_datetime(data.Date, format='%Y-%m-%d')

# %%
data19 = data[(data['Date'].dt.year == 2019)]
data19.head()
# Out:
#    Site_ID Grade_Description       Date  Price  Fuel Cost  Profit   Volume  \
# 0    10808       Premium Gas 2019-01-01  2.319   1.534257    7.60    49.30
# 1    10808      Unleaded Gas 2019-01-01  1.769   1.323700    9.73  1092.01
# 2    10808       Premium Gas 2019-01-02  2.309   1.535803   14.78    83.84
# 3    10808      Unleaded Gas 2019-01-02  1.759   1.325600   11.13  1955.47
# 4    10808       Premium Gas 2019-01-03  2.299   1.553484    7.15    56.94
#
#    Competitor_Price
# 0          1.799000
# 1          1.825667
# 2          1.799000
# 3          1.819000
# 4          1.799000

# %%
data20 = data[(data['Date'].dt.year == 2020)]
data20.head()
# Out:
#      Site_ID Grade_Description       Date  Price  Fuel Cost  Profit  Volume  \
# 545    10808      Midgrade Gas 2020-01-01  2.519   1.770276     5.0    16.0
# 546    10808       Premium Gas 2020-01-01  2.709   1.901883     8.0    18.0
# 547    10808      Unleaded Gas 2020-01-01  2.159   1.697800    25.0   831.0
# 548    10808      Midgrade Gas 2020-01-02  2.519   1.814170    16.0    48.0
# 549    10808       Premium Gas 2020-01-02  2.709   1.883521    36.0    79.0
#
#      Competitor_Price
# 545          2.372333
# 546          2.565667
# 547          2.159000
# 548          2.359000
# 549          2.574000

# %%
import plotly.express as px
fig = px.line(data19, x="Date", y=["Profit"], template = 'plotly_dark')
fig.show()
# Out:
# <div>                            <div id="f111e4db-51f8-48a6-b0e1-fcaf6c3cdba5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f111e4db-51f8-48a6-b0e1-fcaf6c3cdba5")) {                    Plotly.newPlot(                        "f111e4db-51f8-48a6-b0e1-fcaf6c3cdba5",                        [{"hovertemplate": "variable=Profit<br>Date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Profit", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Profit", "showlegend": true, "type": "scattergl", "x": ["2019-01-01T00:00:00", "2019-01-01T00:00:00", "2019-01-02T00:00:00", "2019-01-02T00:00:00", "2019-01-03T00:00:00", "2019-01-03T00:00:00", "2019-01-04T00:00:00", "2019-01-04T00:00:00", "2019-01-05T00:00:00", "2019-01-05T00:00:00", "201
# ...
